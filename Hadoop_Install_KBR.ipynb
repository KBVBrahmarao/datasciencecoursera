# %% [markdown]
# <a href="https://colab.research.google.com/github/KBVBrahmarao/datasciencecoursera/blob/main/Hadoop_Install_KBR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#STEP 1 — Install Java
# !apt-get update -qq
# !apt-get install -y openjdk-17-jdk-headless
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# openjdk-17-jdk-headless is already the newest version (17.0.17+10-1~22.04).
# 0 upgraded, 0 newly installed, 0 to remove and 65 not upgraded.

# %%
#Check Java:
# !java -version
# Out:
# openjdk version "17.0.17" 2025-10-21
# OpenJDK Runtime Environment (build 17.0.17+10-Ubuntu-122.04)
# OpenJDK 64-Bit Server VM (build 17.0.17+10-Ubuntu-122.04, mixed mode, sharing)

# %%
#STEP 2 — Set Java Environment Variables
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-17-openjdk-amd64"
os.environ["PATH"] += ":/usr/lib/jvm/java-17-openjdk-amd64/bin"

# %%
#STEP 3 — Download and Extract Hadoop
# !wget -q https://dlcdn.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz
# !tar -xzf hadoop-3.3.6.tar.gz
# !mv hadoop-3.3.6 /content/hadoop

# %%
#STEP 4 — Set Hadoop Environment Variables
os.environ["HADOOP_HOME"] = "/content/hadoop"
os.environ["HADOOP_CONF_DIR"] = "/content/hadoop/etc/hadoop"
os.environ["PATH"] += ":/content/hadoop/bin:/content/hadoop/sbin"

# %%
#Extra STEP 1 — Set JAVA_HOME again
# !export HADOOP_HOME=/content/Hadoop
# !export JAVA_HOME=/usr/lib/jvm/java-17-openjdk-amd64
# !export PATH=$PATH:$JAVA_HOME/bin:$HADOOP_HOME/bin:$HADOOP_HOME/sbin

# %%
#Extra Step 2 — Verify directories
# !ls /content/Hadoop/bin
# Out:
# container-executor  hdfs      mapred.cmd	       yarn
# hadoop		    hdfs.cmd  oom-listener	       yarn.cmd
# hadoop.cmd	    mapred    test-container-executor

# %%
#ExtraSTEP 3 — Check Hadoop version again
# !export HADOOP_HOME=/content/Hadoop && export JAVA_HOME=/usr/lib/jvm/java-17-openjdk-amd64 && export PATH=$PATH:$JAVA_HOME/bin:$HADOOP_HOME/bin:$HADOOP_HOME/sbin && hadoop version
# Out:
# WARNING: log4j.properties is not found. HADOOP_CONF_DIR may be incomplete.
# Hadoop 3.3.6
# Source code repository https://github.com/apache/hadoop.git -r 1be78238728da9266a4f88195058f08fd012bf9c
# Compiled by ubuntu on 2023-06-18T08:22Z
# Compiled on platform linux-x86_64
# Compiled with protoc 3.7.1
# From source with checksum 5652179ad55f76cb287d9c633bb53bbd
# This command was run using /content/Hadoop/share/hadoop/common/hadoop-common-3.3.6.jar

# %%
#STEP 5 — Correct Hadoop Configuration Files - core-site.xml
# %%writefile /content/Hadoop/etc/hadoop/core-site.xml
<?xml version="1.0"?>
<configuration>
    <property>
        <name>fs.defaultFS</name>
        <value>file:///</value>
    </property>
</configuration>
# Out:
# Overwriting /content/Hadoop/etc/hadoop/core-site.xml

# %%
#Step 6 - Create hdfs-site.xml (even though HDFS cannot run in Colab)
#Step 6 - Create hdfs-site.xml (even though HDFS cannot run in Colab)
# %%writefile /content/Hadoop/etc/hadoop/hdfs-site.xml
<?xml version="1.0"?>
<configuration>
    <property>
        <name>dfs.replication</name>
        <value>1</value>
    </property>
</configuration>
# Out:
# Overwriting /content/Hadoop/etc/hadoop/hdfs-site.xml

# %%
#STEP  7A — Verify that files are correct
# !cat /content/Hadoop/etc/hadoop/core-site.xml
# !cat /content/Hadoop/etc/hadoop/hdfs-site.xml
# Out:
# <?xml version="1.0"?>
# <configuration>
#     <property>
#         <name>fs.defaultFS</name>
#         <value>file:///</value>
#     </property>
# </configuration>
# <?xml version="1.0"?>
# <configuration>
#     <property>
#         <name>dfs.replication</name>
#         <value>1</value>
#     </property>
# </configuration>

# %%
#Step 7B - Verify the files were created
# !ls /content/Hadoop/etc/hadoop
# Out:
# capacity-scheduler.xml		  kms-log4j.properties
# configuration.xsl		  kms-site.xml
# container-executor.cfg		  log4j.properties
# core-site.xml			  mapred-env.cmd
# hadoop-env.cmd			  mapred-env.sh
# hadoop-env.sh			  mapred-queues.xml.template
# hadoop-metrics2.properties	  mapred-site.xml
# hadoop-policy.xml		  shellprofile.d
# hadoop-user-functions.sh.example  ssl-client.xml.example
# hdfs-rbf-site.xml		  ssl-server.xml.example
# hdfs-site.xml			  user_ec_policies.xml.template
# httpfs-env.sh			  workers
# httpfs-log4j.properties		  yarn-env.cmd
# httpfs-site.xml			  yarn-env.sh
# kms-acls.xml			  yarnservice-log4j.properties
# kms-env.sh			  yarn-site.xml

# %%
#STEP 7C — Set correct config directory
# %%bash
export HADOOP_HOME=/content/Hadoop
export HADOOP_CONF_DIR=/content/Hadoop/etc/hadoop
export JAVA_HOME=/usr/lib/jvm/java-17-openjdk-amd64
export PATH=$PATH:$JAVA_HOME/bin:$HADOOP_HOME/bin:$HADOOP_HOME/sbin

hadoop version
# Out:
# Hadoop 3.3.6
# Source code repository https://github.com/apache/hadoop.git -r 1be78238728da9266a4f88195058f08fd012bf9c
# Compiled by ubuntu on 2023-06-18T08:22Z
# Compiled on platform linux-x86_64
# Compiled with protoc 3.7.1
# From source with checksum 5652179ad55f76cb287d9c633bb53bbd
# This command was run using /content/Hadoop/share/hadoop/common/hadoop-common-3.3.6.jar

# %%
#STEP 7D — Delete old output
# !rm -rf output

# %%
#NEXT IMPORTANT STEPs
#STEP 7 - Fix log4j warning (optional but recommended)
# %%bash
cat > /content/Hadoop/etc/hadoop/log4j.properties <<'EOF'
log4j.rootLogger=INFO, console
log4j.appender.console=org.apache.log4j.ConsoleAppender
log4j.appender.console.target=System.err
log4j.appender.console.layout=org.apache.log4j.PatternLayout
log4j.appender.console.layout.ConversionPattern=%d{ISO8601} %-5p %c: %m%n
EOF

# %%
#STEP 8 — Export Hadoop Environment Variables (for each session)
# %%bash
export HADOOP_HOME=/content/Hadoop
export JAVA_HOME=/usr/lib/jvm/java-17-openjdk-amd64
export PATH=$PATH:$JAVA_HOME/bin:$HADOOP_HOME/bin:$HADOOP_HOME/sbin

hadoop version
# Out:
# Hadoop 3.3.6
# Source code repository https://github.com/apache/hadoop.git -r 1be78238728da9266a4f88195058f08fd012bf9c
# Compiled by ubuntu on 2023-06-18T08:22Z
# Compiled on platform linux-x86_64
# Compiled with protoc 3.7.1
# From source with checksum 5652179ad55f76cb287d9c633bb53bbd
# This command was run using /content/Hadoop/share/hadoop/common/hadoop-common-3.3.6.jar
# WARNING: log4j.properties is not found. HADOOP_CONF_DIR may be incomplete.

# %%
# %%bash
# export HADOOP_HOME=/content/Hadoop
# export HADOOP_CONF_DIR=/content/Hadoop/etc/hadoop
# export JAVA_HOME=/usr/lib/jvm/java-17-openjdk-amd64
# export PATH=$PATH:$JAVA_HOME/bin:$HADOOP_HOME/bin:$HADOOP_HOME/sbin
#
# hadoop version
# Out:
# Hadoop 3.3.6
# Source code repository https://github.com/apache/hadoop.git -r 1be78238728da9266a4f88195058f08fd012bf9c
# Compiled by ubuntu on 2023-06-18T08:22Z
# Compiled on platform linux-x86_64
# Compiled with protoc 3.7.1
# From source with checksum 5652179ad55f76cb287d9c633bb53bbd
# This command was run using /content/Hadoop/share/hadoop/common/hadoop-common-3.3.6.jar

# %%
# %%bash
# export HADOOP_HOME=/content/Hadoop
# export HADOOP_CONF_DIR=$HADOOP_HOME/etc/hadoop
# export JAVA_HOME=/usr/lib/jvm/java-17-openjdk-amd64
# export PATH=$PATH:$JAVA_HOME/bin:$HADOOP_HOME/bin:$HADOOP_HOME/sbin
#
# echo "HADOOP_HOME=$HADOOP_HOME"
# echo "HADOOP_CONF_DIR=$HADOOP_CONF_DIR"
# echo "JAVA_HOME=$JAVA_HOME"
# which hadoop || true
# hadoop classpath
# Out:
# HADOOP_HOME=/content/Hadoop
# HADOOP_CONF_DIR=/content/Hadoop/etc/hadoop
# JAVA_HOME=/usr/lib/jvm/java-17-openjdk-amd64
# /content/Hadoop/bin/hadoop
# /content/Hadoop/etc/hadoop:/content/Hadoop/share/hadoop/common/lib/*:/content/Hadoop/share/hadoop/common/*:/content/Hadoop/share/hadoop/hdfs:/content/Hadoop/share/hadoop/hdfs/lib/*:/content/Hadoop/share/hadoop/hdfs/*:/content/Hadoop/share/hadoop/mapreduce/*:/content/Hadoop/share/hadoop/yarn:/content/Hadoop/share/hadoop/yarn/lib/*:/content/Hadoop/share/hadoop/yarn/*

# %%
#STEP 9 — Run a Sample MapReduce Job (IMPORTANT TEST)
#Create an input file:
# %%bash
echo "hello hadoop hello colab" > input.txt

# %%
#STEP 9B - Delete any old output
# !rm -rf output

# %%
#STEP 10 - Run WordCount MapReduce:
# %%bash
export HADOOP_HOME=/content/Hadoop
export HADOOP_CONF_DIR=/content/Hadoop/etc/hadoop
export JAVA_HOME=/usr/lib/jvm/java-17-openjdk-amd64
export PATH=$PATH:$JAVA_HOME/bin:$HADOOP_HOME/bin:$HADOOP_HOME/sbin

$HADOOP_HOME/bin/hadoop jar \
$HADOOP_HOME/share/hadoop/mapreduce/hadoop-mapreduce-examples-3.3.6.jar \
wordcount input.txt output
# Out:
# 2025-12-09 06:42:18,627 INFO  org.apache.hadoop.metrics2.impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2025-12-09 06:42:18,892 INFO  org.apache.hadoop.metrics2.impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2025-12-09 06:42:18,893 INFO  org.apache.hadoop.metrics2.impl.MetricsSystemImpl: JobTracker metrics system started
# 2025-12-09 06:42:19,330 INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat: Total input files to process : 1
# 2025-12-09 06:42:19,389 INFO  org.apache.hadoop.mapreduce.JobSubmitter: number of splits:1
# 2025-12-09 06:42:20,026 INFO  org.apache.hadoop.mapreduce.JobSubmitter: Submitting tokens for job: job_local1195022286_0001
# 2025-12-09 06:42:20,027 INFO  org.apache.hadoop.mapreduce.JobSubmitter: Executing with tokens: []
# 2025-12-09 06:42:20,632 INFO  org.apache.hadoop.mapreduce.Job: The url to track the job: http://localhost:8080/
# 2025-12-09 06:42:20,634 INFO  org.apache.hadoop.mapred.LocalJobRunner: OutputCommitter set in config null
# 2025-12-09 06:42:20,634 INFO  org.apache.hadoop.mapreduce.Job: Running job: job_local1195022286_0001
# 2025-12-09 06:42:20,656 INFO  org.apache.hadoop.mapreduce.lib.output.PathOutputCommitterFactory: No output committer factory defined, defaulting to FileOutputCommitterFactory
# 2025-12-09 06:42:20,661 INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-12-09 06:42:20,662 INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-12-09 06:42:20,664 INFO  org.apache.hadoop.mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter
# 2025-12-09 06:42:20,796 INFO  org.apache.hadoop.mapred.LocalJobRunner: Waiting for map tasks
# 2025-12-09 06:42:20,797 INFO  org.apache.hadoop.mapred.LocalJobRunner: Starting task: attempt_local1195022286_0001_m_000000_0
# 2025-12-09 06:42:20,880 INFO  org.apache.hadoop.mapreduce.lib.output.PathOutputCommitterFactory: No output committer factory defined, defaulting to FileOutputCommitterFactory
# 2025-12-09 06:42:20,881 INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-12-09 06:42:20,881 INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-12-09 06:42:20,950 INFO  org.apache.hadoop.mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2025-12-09 06:42:20,967 INFO  org.apache.hadoop.mapred.MapTask: Processing split: file:/content/input.txt:0+25
# 2025-12-09 06:42:21,451 INFO  org.apache.hadoop.mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2025-12-09 06:42:21,452 INFO  org.apache.hadoop.mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2025-12-09 06:42:21,452 INFO  org.apache.hadoop.mapred.MapTask: soft limit at 83886080
# 2025-12-09 06:42:21,452 INFO  org.apache.hadoop.mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2025-12-09 06:42:21,452 INFO  org.apache.hadoop.mapred.MapTask: kvstart = 26214396; length = 6553600
# 2025-12-09 06:42:21,461 INFO  org.apache.hadoop.mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2025-12-09 06:42:21,485 INFO  org.apache.hadoop.mapred.LocalJobRunner:
# 2025-12-09 06:42:21,487 INFO  org.apache.hadoop.mapred.MapTask: Starting flush of map output
# 2025-12-09 06:42:21,488 INFO  org.apache.hadoop.mapred.MapTask: Spilling map output
# 2025-12-09 06:42:21,488 INFO  org.apache.hadoop.mapred.MapTask: bufstart = 0; bufend = 41; bufvoid = 104857600
# 2025-12-09 06:42:21,489 INFO  org.apache.hadoop.mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214384(104857536); length = 13/6553600
# 2025-12-09 06:42:21,527 INFO  org.apache.hadoop.mapred.MapTask: Finished spill 0
# 2025-12-09 06:42:21,570 INFO  org.apache.hadoop.mapred.Task: Task:attempt_local1195022286_0001_m_000000_0 is done. And is in the process of committing
# 2025-12-09 06:42:21,578 INFO  org.apache.hadoop.mapred.LocalJobRunner: map
# 2025-12-09 06:42:21,578 INFO  org.apache.hadoop.mapred.Task: Task 'attempt_local1195022286_0001_m_000000_0' done.
# 2025-12-09 06:42:21,596 INFO  org.apache.hadoop.mapred.Task: Final Counters for attempt_local1195022286_0001_m_000000_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=281515
# 		FILE: Number of bytes written=919648
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1
# 		Map output records=4
# 		Map output bytes=41
# 		Map output materialized bytes=43
# 		Input split bytes=88
# 		Combine input records=4
# 		Combine output records=3
# 		Spilled Records=3
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=31
# 		Total committed heap usage (bytes)=270532608
# 	File Input Format Counters
# 		Bytes Read=25
# 2025-12-09 06:42:21,596 INFO  org.apache.hadoop.mapred.LocalJobRunner: Finishing task: attempt_local1195022286_0001_m_000000_0
# 2025-12-09 06:42:21,598 INFO  org.apache.hadoop.mapred.LocalJobRunner: map task executor complete.
# 2025-12-09 06:42:21,608 INFO  org.apache.hadoop.mapred.LocalJobRunner: Waiting for reduce tasks
# 2025-12-09 06:42:21,609 INFO  org.apache.hadoop.mapred.LocalJobRunner: Starting task: attempt_local1195022286_0001_r_000000_0
# 2025-12-09 06:42:21,631 INFO  org.apache.hadoop.mapreduce.lib.output.PathOutputCommitterFactory: No output committer factory defined, defaulting to FileOutputCommitterFactory
# 2025-12-09 06:42:21,632 INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-12-09 06:42:21,632 INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-12-09 06:42:21,632 INFO  org.apache.hadoop.mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2025-12-09 06:42:21,641 INFO  org.apache.hadoop.mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@2b5ec8e2
# 2025-12-09 06:42:21,646 WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2025-12-09 06:42:21,662 INFO  org.apache.hadoop.mapreduce.Job: Job job_local1195022286_0001 running in uber mode : false
# 2025-12-09 06:42:21,664 INFO  org.apache.hadoop.mapreduce.Job:  map 100% reduce 0%
# 2025-12-09 06:42:21,702 INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl: MergerManager: memoryLimit=2381106432, maxSingleShuffleLimit=595276608, mergeThreshold=1571530368, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2025-12-09 06:42:21,709 INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher: attempt_local1195022286_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2025-12-09 06:42:21,783 INFO  org.apache.hadoop.mapreduce.task.reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1195022286_0001_m_000000_0 decomp: 39 len: 43 to MEMORY
# 2025-12-09 06:42:21,790 INFO  org.apache.hadoop.mapreduce.task.reduce.InMemoryMapOutput: Read 39 bytes from map-output for attempt_local1195022286_0001_m_000000_0
# 2025-12-09 06:42:21,792 INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 39, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->39
# 2025-12-09 06:42:21,797 INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2025-12-09 06:42:21,798 INFO  org.apache.hadoop.mapred.LocalJobRunner: 1 / 1 copied.
# 2025-12-09 06:42:21,798 INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2025-12-09 06:42:21,815 INFO  org.apache.hadoop.mapred.Merger: Merging 1 sorted segments
# 2025-12-09 06:42:21,815 INFO  org.apache.hadoop.mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 31 bytes
# 2025-12-09 06:42:21,820 INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl: Merged 1 segments, 39 bytes to disk to satisfy reduce memory limit
# 2025-12-09 06:42:21,821 INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl: Merging 1 files, 43 bytes from disk
# 2025-12-09 06:42:21,826 INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2025-12-09 06:42:21,826 INFO  org.apache.hadoop.mapred.Merger: Merging 1 sorted segments
# 2025-12-09 06:42:21,830 INFO  org.apache.hadoop.mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 31 bytes
# 2025-12-09 06:42:21,831 INFO  org.apache.hadoop.mapred.LocalJobRunner: 1 / 1 copied.
# 2025-12-09 06:42:21,837 INFO  org.apache.hadoop.conf.Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2025-12-09 06:42:21,846 INFO  org.apache.hadoop.mapred.Task: Task:attempt_local1195022286_0001_r_000000_0 is done. And is in the process of committing
# 2025-12-09 06:42:21,850 INFO  org.apache.hadoop.mapred.LocalJobRunner: 1 / 1 copied.
# 2025-12-09 06:42:21,850 INFO  org.apache.hadoop.mapred.Task: Task attempt_local1195022286_0001_r_000000_0 is allowed to commit now
# 2025-12-09 06:42:21,857 INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: Saved output of task 'attempt_local1195022286_0001_r_000000_0' to file:/content/output
# 2025-12-09 06:42:21,863 INFO  org.apache.hadoop.mapred.LocalJobRunner: reduce > reduce
# 2025-12-09 06:42:21,863 INFO  org.apache.hadoop.mapred.Task: Task 'attempt_local1195022286_0001_r_000000_0' done.
# 2025-12-09 06:42:21,865 INFO  org.apache.hadoop.mapred.Task: Final Counters for attempt_local1195022286_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=281633
# 		FILE: Number of bytes written=919728
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=3
# 		Reduce shuffle bytes=43
# 		Reduce input records=3
# 		Reduce output records=3
# 		Spilled Records=3
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=270532608
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=37
# 2025-12-09 06:42:21,865 INFO  org.apache.hadoop.mapred.LocalJobRunner: Finishing task: attempt_local1195022286_0001_r_000000_0
# 2025-12-09 06:42:21,865 INFO  org.apache.hadoop.mapred.LocalJobRunner: reduce task executor complete.
# 2025-12-09 06:42:22,675 INFO  org.apache.hadoop.mapreduce.Job:  map 100% reduce 100%
# 2025-12-09 06:42:22,676 INFO  org.apache.hadoop.mapreduce.Job: Job job_local1195022286_0001 completed successfully
# 2025-12-09 06:42:22,685 INFO  org.apache.hadoop.mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=563148
# 		FILE: Number of bytes written=1839376
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1
# 		Map output records=4
# 		Map output bytes=41
# 		Map output materialized bytes=43
# 		Input split bytes=88
# 		Combine input records=4
# 		Combine output records=3
# 		Reduce input groups=3
# 		Reduce shuffle bytes=43
# 		Reduce input records=3
# 		Reduce output records=3
# 		Spilled Records=6
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=31
# 		Total committed heap usage (bytes)=541065216
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=25
# 	File Output Format Counters
# 		Bytes Written=37

# %%
#Show output:
# !cat output/part-r-00000
# Out:
# colab	1
# hadoop	1
# hello	2
