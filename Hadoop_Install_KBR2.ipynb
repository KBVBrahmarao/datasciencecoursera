# %% [markdown]
# <a href="https://colab.research.google.com/github/KBVBrahmarao/datasciencecoursera/blob/main/Hadoop_Install_KBR2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#STEP 1 — Install Java
# !apt-get update -qq
# !apt-get install -y openjdk-17-jdk-headless
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# openjdk-17-jdk-headless is already the newest version (17.0.17+10-1~22.04).
# 0 upgraded, 0 newly installed, 0 to remove and 65 not upgraded.

# %%
#Check Java:
# !java -version
# Out:
# openjdk version "17.0.17" 2025-10-21
# OpenJDK Runtime Environment (build 17.0.17+10-Ubuntu-122.04)
# OpenJDK 64-Bit Server VM (build 17.0.17+10-Ubuntu-122.04, mixed mode, sharing)

# %%
#STEP 2 — Set Java Environment Variables
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-17-openjdk-amd64"
os.environ["PATH"] += ":/usr/lib/jvm/java-17-openjdk-amd64/bin"

# %%
#STEP 3 — Download and Extract Hadoop
# !wget -q https://dlcdn.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz
# !tar -xzf hadoop-3.3.6.tar.gz
# !mv hadoop-3.3.6 /content/hadoop

# %%
#STEP 4 — Set Hadoop Environment Variables
os.environ["HADOOP_HOME"] = "/content/hadoop"
os.environ["HADOOP_CONF_DIR"] = "/content/hadoop/etc/hadoop"
os.environ["PATH"] += ":/content/hadoop/bin:/content/hadoop/sbin"

# %%
#Extra STEP 1 — Set JAVA_HOME again
# !export HADOOP_HOME=/content/Hadoop
# !export JAVA_HOME=/usr/lib/jvm/java-17-openjdk-amd64
# !export PATH=$PATH:$JAVA_HOME/bin:$HADOOP_HOME/bin:$HADOOP_HOME/sbin

# %%
#Extra Step 2 — Verify directories
# !ls /content/Hadoop/bin
# Out:
# container-executor  hdfs      mapred.cmd	       yarn
# hadoop		    hdfs.cmd  oom-listener	       yarn.cmd
# hadoop.cmd	    mapred    test-container-executor

# %%
#ExtraSTEP 3 — Check Hadoop version again
# !export HADOOP_HOME=/content/Hadoop && export JAVA_HOME=/usr/lib/jvm/java-17-openjdk-amd64 && export PATH=$PATH:$JAVA_HOME/bin:$HADOOP_HOME/bin:$HADOOP_HOME/sbin && hadoop version
# Out:
# WARNING: log4j.properties is not found. HADOOP_CONF_DIR may be incomplete.
# Hadoop 3.3.6
# Source code repository https://github.com/apache/hadoop.git -r 1be78238728da9266a4f88195058f08fd012bf9c
# Compiled by ubuntu on 2023-06-18T08:22Z
# Compiled on platform linux-x86_64
# Compiled with protoc 3.7.1
# From source with checksum 5652179ad55f76cb287d9c633bb53bbd
# This command was run using /content/Hadoop/share/hadoop/common/hadoop-common-3.3.6.jar

# %%
#STEP 5 — Correct Hadoop Configuration Files - core-site.xml
# %%writefile /content/hadoop/etc/hadoop/core-site.xml
<?xml version="1.0"?>
<configuration>
    <property>
        <name>fs.defaultFS</name>
        <value>file:///</value>
    </property>
</configuration>
# Out:
# Overwriting /content/hadoop/etc/hadoop/core-site.xml

# %%
#Step 6 - Create hdfs-site.xml (even though HDFS cannot run in Colab)
#Step 6 - Create hdfs-site.xml (even though HDFS cannot run in Colab)
# %%writefile /content/hadoop/etc/hadoop/hdfs-site.xml
<?xml version="1.0"?>
<configuration>
    <property>
        <name>dfs.replication</name>
        <value>1</value>
    </property>
</configuration>
# Out:
# Overwriting /content/hadoop/etc/hadoop/hdfs-site.xml

# %%
#STEP  7A — Verify that files are correct
# !cat /content/hadoop/etc/hadoop/core-site.xml
# !cat /content/hadoop/etc/hadoop/hdfs-site.xml
# Out:
# <?xml version="1.0"?>
# <configuration>
#     <property>
#         <name>fs.defaultFS</name>
#         <value>file:///</value>
#     </property>
# </configuration>
# <?xml version="1.0"?>
# <configuration>
#     <property>
#         <name>dfs.replication</name>
#         <value>1</value>
#     </property>
# </configuration>

# %%
#Step 7B - Verify the files were created
# !ls /content/hadoop/etc/hadoop
# Out:
# capacity-scheduler.xml		  kms-log4j.properties
# configuration.xsl		  kms-site.xml
# container-executor.cfg		  log4j.properties
# core-site.xml			  mapred-env.cmd
# hadoop-env.cmd			  mapred-env.sh
# hadoop-env.sh			  mapred-queues.xml.template
# hadoop-metrics2.properties	  mapred-site.xml
# hadoop-policy.xml		  shellprofile.d
# hadoop-user-functions.sh.example  ssl-client.xml.example
# hdfs-rbf-site.xml		  ssl-server.xml.example
# hdfs-site.xml			  user_ec_policies.xml.template
# httpfs-env.sh			  workers
# httpfs-log4j.properties		  yarn-env.cmd
# httpfs-site.xml			  yarn-env.sh
# kms-acls.xml			  yarnservice-log4j.properties
# kms-env.sh			  yarn-site.xml

# %%
#STEP 7C — Set correct config directory
# %%bash
export HADOOP_HOME=/content/hadoop
export HADOOP_CONF_DIR=/content/hadoop/etc/hadoop
export JAVA_HOME=/usr/lib/jvm/java-17-openjdk-amd64
export PATH=$PATH:$JAVA_HOME/bin:$HADOOP_HOME/bin:$HADOOP_HOME/sbin

hadoop version
# Out:
# Hadoop 3.3.6
# Source code repository https://github.com/apache/hadoop.git -r 1be78238728da9266a4f88195058f08fd012bf9c
# Compiled by ubuntu on 2023-06-18T08:22Z
# Compiled on platform linux-x86_64
# Compiled with protoc 3.7.1
# From source with checksum 5652179ad55f76cb287d9c633bb53bbd
# This command was run using /content/hadoop/share/hadoop/common/hadoop-common-3.3.6.jar

# %%
#STEP 7D — Delete old output
# !rm -rf output

# %%
#NEXT IMPORTANT STEPs
#STEP 7 - Fix log4j warning (optional but recommended)
# %%bash
cat > /content/hadoop/etc/hadoop/log4j.properties <<'EOF'
log4j.rootLogger=INFO, console
log4j.appender.console=org.apache.log4j.ConsoleAppender
log4j.appender.console.target=System.err
log4j.appender.console.layout=org.apache.log4j.PatternLayout
log4j.appender.console.layout.ConversionPattern=%d{ISO8601} %-5p %c: %m%n
EOF

# %%
#STEP 8 — Run a Sample MapReduce Job (IMPORTANT TEST)
#Create an input file:
# %%bash
cat << EOF > lineinput.txt
hello
big data
hadoop mapreduce
EOF

# %%
#STEP 8.1
# %%bash
hdfs dfs -mkdir -p /lineinput
hdfs dfs -put -f lineinput.txt /lineinput
hdfs dfs -ls /lineinput
# Out:
# Found 1 items
# -rw-r--r--   1 root root         32 2025-12-16 05:59 /lineinput/lineinput.txt

# %%
#Run MapReduce Example (Line Length)
#Hadoop already provides example JARs.
# %%bash
export JAVA_HOME=/usr/lib/jvm/java-17-openjdk-amd64
export HADOOP_HOME=/content/hadoop
export PATH=$PATH:$JAVA_HOME/bin:$HADOOP_HOME/bin:$HADOOP_HOME/sbin

hdfs dfs -rm -r /lineoutput

hadoop jar \
$HADOOP_HOME/share/hadoop/mapreduce/hadoop-mapreduce-examples-3.3.6.jar \
grep /lineinput /lineoutput '.*'
# Out:
# rm: `/lineoutput': No such file or directory
# 2025-12-16 06:20:24,258 INFO  org.apache.hadoop.metrics2.impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2025-12-16 06:20:24,780 INFO  org.apache.hadoop.metrics2.impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2025-12-16 06:20:24,781 INFO  org.apache.hadoop.metrics2.impl.MetricsSystemImpl: JobTracker metrics system started
# 2025-12-16 06:20:25,488 INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat: Total input files to process : 1
# 2025-12-16 06:20:25,625 INFO  org.apache.hadoop.mapreduce.JobSubmitter: number of splits:1
# 2025-12-16 06:20:26,183 INFO  org.apache.hadoop.mapreduce.JobSubmitter: Submitting tokens for job: job_local1711478750_0001
# 2025-12-16 06:20:26,183 INFO  org.apache.hadoop.mapreduce.JobSubmitter: Executing with tokens: []
# 2025-12-16 06:20:26,519 INFO  org.apache.hadoop.mapreduce.Job: The url to track the job: http://localhost:8080/
# 2025-12-16 06:20:26,520 INFO  org.apache.hadoop.mapreduce.Job: Running job: job_local1711478750_0001
# 2025-12-16 06:20:26,522 INFO  org.apache.hadoop.mapred.LocalJobRunner: OutputCommitter set in config null
# 2025-12-16 06:20:26,540 INFO  org.apache.hadoop.mapreduce.lib.output.PathOutputCommitterFactory: No output committer factory defined, defaulting to FileOutputCommitterFactory
# 2025-12-16 06:20:26,542 INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-12-16 06:20:26,542 INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-12-16 06:20:26,543 INFO  org.apache.hadoop.mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter
# 2025-12-16 06:20:26,613 INFO  org.apache.hadoop.mapred.LocalJobRunner: Waiting for map tasks
# 2025-12-16 06:20:26,614 INFO  org.apache.hadoop.mapred.LocalJobRunner: Starting task: attempt_local1711478750_0001_m_000000_0
# 2025-12-16 06:20:26,677 INFO  org.apache.hadoop.mapreduce.lib.output.PathOutputCommitterFactory: No output committer factory defined, defaulting to FileOutputCommitterFactory
# 2025-12-16 06:20:26,677 INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-12-16 06:20:26,677 INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-12-16 06:20:26,741 INFO  org.apache.hadoop.mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2025-12-16 06:20:26,757 INFO  org.apache.hadoop.mapred.MapTask: Processing split: file:/lineinput/lineinput.txt:0+32
# 2025-12-16 06:20:27,172 INFO  org.apache.hadoop.mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2025-12-16 06:20:27,172 INFO  org.apache.hadoop.mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2025-12-16 06:20:27,172 INFO  org.apache.hadoop.mapred.MapTask: soft limit at 83886080
# 2025-12-16 06:20:27,172 INFO  org.apache.hadoop.mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2025-12-16 06:20:27,172 INFO  org.apache.hadoop.mapred.MapTask: kvstart = 26214396; length = 6553600
# 2025-12-16 06:20:27,181 INFO  org.apache.hadoop.mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2025-12-16 06:20:27,202 INFO  org.apache.hadoop.mapred.LocalJobRunner:
# 2025-12-16 06:20:27,204 INFO  org.apache.hadoop.mapred.MapTask: Starting flush of map output
# 2025-12-16 06:20:27,205 INFO  org.apache.hadoop.mapred.MapTask: Spilling map output
# 2025-12-16 06:20:27,205 INFO  org.apache.hadoop.mapred.MapTask: bufstart = 0; bufend = 83; bufvoid = 104857600
# 2025-12-16 06:20:27,205 INFO  org.apache.hadoop.mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214376(104857504); length = 21/6553600
# 2025-12-16 06:20:27,226 INFO  org.apache.hadoop.mapred.MapTask: Finished spill 0
# 2025-12-16 06:20:27,264 INFO  org.apache.hadoop.mapred.Task: Task:attempt_local1711478750_0001_m_000000_0 is done. And is in the process of committing
# 2025-12-16 06:20:27,270 INFO  org.apache.hadoop.mapred.LocalJobRunner: map
# 2025-12-16 06:20:27,270 INFO  org.apache.hadoop.mapred.Task: Task 'attempt_local1711478750_0001_m_000000_0' done.
# 2025-12-16 06:20:27,298 INFO  org.apache.hadoop.mapred.Task: Final Counters for attempt_local1711478750_0001_m_000000_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=281544
# 		FILE: Number of bytes written=920576
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=3
# 		Map output records=6
# 		Map output bytes=83
# 		Map output materialized bytes=79
# 		Input split bytes=94
# 		Combine input records=6
# 		Combine output records=4
# 		Spilled Records=4
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=283115520
# 	File Input Format Counters
# 		Bytes Read=48
# 2025-12-16 06:20:27,298 INFO  org.apache.hadoop.mapred.LocalJobRunner: Finishing task: attempt_local1711478750_0001_m_000000_0
# 2025-12-16 06:20:27,300 INFO  org.apache.hadoop.mapred.LocalJobRunner: map task executor complete.
# 2025-12-16 06:20:27,308 INFO  org.apache.hadoop.mapred.LocalJobRunner: Waiting for reduce tasks
# 2025-12-16 06:20:27,308 INFO  org.apache.hadoop.mapred.LocalJobRunner: Starting task: attempt_local1711478750_0001_r_000000_0
# 2025-12-16 06:20:27,322 INFO  org.apache.hadoop.mapreduce.lib.output.PathOutputCommitterFactory: No output committer factory defined, defaulting to FileOutputCommitterFactory
# 2025-12-16 06:20:27,322 INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-12-16 06:20:27,322 INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-12-16 06:20:27,323 INFO  org.apache.hadoop.mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2025-12-16 06:20:27,327 INFO  org.apache.hadoop.mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@38f10d96
# 2025-12-16 06:20:27,329 WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2025-12-16 06:20:27,363 INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl: MergerManager: memoryLimit=2381106432, maxSingleShuffleLimit=595276608, mergeThreshold=1571530368, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2025-12-16 06:20:27,369 INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher: attempt_local1711478750_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2025-12-16 06:20:27,438 INFO  org.apache.hadoop.mapreduce.task.reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1711478750_0001_m_000000_0 decomp: 75 len: 79 to MEMORY
# 2025-12-16 06:20:27,446 INFO  org.apache.hadoop.mapreduce.task.reduce.InMemoryMapOutput: Read 75 bytes from map-output for attempt_local1711478750_0001_m_000000_0
# 2025-12-16 06:20:27,450 INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 75, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->75
# 2025-12-16 06:20:27,453 INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2025-12-16 06:20:27,455 INFO  org.apache.hadoop.mapred.LocalJobRunner: 1 / 1 copied.
# 2025-12-16 06:20:27,456 INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2025-12-16 06:20:27,493 INFO  org.apache.hadoop.mapred.Merger: Merging 1 sorted segments
# 2025-12-16 06:20:27,493 INFO  org.apache.hadoop.mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 72 bytes
# 2025-12-16 06:20:27,496 INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl: Merged 1 segments, 75 bytes to disk to satisfy reduce memory limit
# 2025-12-16 06:20:27,499 INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl: Merging 1 files, 79 bytes from disk
# 2025-12-16 06:20:27,500 INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2025-12-16 06:20:27,501 INFO  org.apache.hadoop.mapred.Merger: Merging 1 sorted segments
# 2025-12-16 06:20:27,505 INFO  org.apache.hadoop.mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 72 bytes
# 2025-12-16 06:20:27,506 INFO  org.apache.hadoop.mapred.LocalJobRunner: 1 / 1 copied.
# 2025-12-16 06:20:27,536 INFO  org.apache.hadoop.conf.Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2025-12-16 06:20:27,538 INFO  org.apache.hadoop.mapreduce.Job: Job job_local1711478750_0001 running in uber mode : false
# 2025-12-16 06:20:27,541 INFO  org.apache.hadoop.mapreduce.Job:  map 100% reduce 0%
# 2025-12-16 06:20:27,543 INFO  org.apache.hadoop.mapred.Task: Task:attempt_local1711478750_0001_r_000000_0 is done. And is in the process of committing
# 2025-12-16 06:20:27,546 INFO  org.apache.hadoop.mapred.LocalJobRunner: 1 / 1 copied.
# 2025-12-16 06:20:27,547 INFO  org.apache.hadoop.mapred.Task: Task attempt_local1711478750_0001_r_000000_0 is allowed to commit now
# 2025-12-16 06:20:27,551 INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: Saved output of task 'attempt_local1711478750_0001_r_000000_0' to file:/content/grep-temp-1938089632
# 2025-12-16 06:20:27,555 INFO  org.apache.hadoop.mapred.LocalJobRunner: reduce > reduce
# 2025-12-16 06:20:27,555 INFO  org.apache.hadoop.mapred.Task: Task 'attempt_local1711478750_0001_r_000000_0' done.
# 2025-12-16 06:20:27,556 INFO  org.apache.hadoop.mapred.Task: Final Counters for attempt_local1711478750_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=281734
# 		FILE: Number of bytes written=920850
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=4
# 		Reduce shuffle bytes=79
# 		Reduce input records=4
# 		Reduce output records=4
# 		Spilled Records=4
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=19
# 		Total committed heap usage (bytes)=283115520
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=195
# 2025-12-16 06:20:27,557 INFO  org.apache.hadoop.mapred.LocalJobRunner: Finishing task: attempt_local1711478750_0001_r_000000_0
# 2025-12-16 06:20:27,558 INFO  org.apache.hadoop.mapred.LocalJobRunner: reduce task executor complete.
# 2025-12-16 06:20:28,545 INFO  org.apache.hadoop.mapreduce.Job:  map 100% reduce 100%
# 2025-12-16 06:20:28,546 INFO  org.apache.hadoop.mapreduce.Job: Job job_local1711478750_0001 completed successfully
# 2025-12-16 06:20:28,556 INFO  org.apache.hadoop.mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=563278
# 		FILE: Number of bytes written=1841426
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=3
# 		Map output records=6
# 		Map output bytes=83
# 		Map output materialized bytes=79
# 		Input split bytes=94
# 		Combine input records=6
# 		Combine output records=4
# 		Reduce input groups=4
# 		Reduce shuffle bytes=79
# 		Reduce input records=4
# 		Reduce output records=4
# 		Spilled Records=8
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=19
# 		Total committed heap usage (bytes)=566231040
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=48
# 	File Output Format Counters
# 		Bytes Written=195
# 2025-12-16 06:20:28,587 WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2025-12-16 06:20:28,600 INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat: Total input files to process : 1
# 2025-12-16 06:20:28,605 INFO  org.apache.hadoop.mapreduce.JobSubmitter: number of splits:1
# 2025-12-16 06:20:28,626 INFO  org.apache.hadoop.mapreduce.JobSubmitter: Submitting tokens for job: job_local1082094662_0002
# 2025-12-16 06:20:28,626 INFO  org.apache.hadoop.mapreduce.JobSubmitter: Executing with tokens: []
# 2025-12-16 06:20:28,780 INFO  org.apache.hadoop.mapred.LocalJobRunner: OutputCommitter set in config null
# 2025-12-16 06:20:28,781 INFO  org.apache.hadoop.mapreduce.lib.output.PathOutputCommitterFactory: No output committer factory defined, defaulting to FileOutputCommitterFactory
# 2025-12-16 06:20:28,781 INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-12-16 06:20:28,781 INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-12-16 06:20:28,781 INFO  org.apache.hadoop.mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter
# 2025-12-16 06:20:28,782 INFO  org.apache.hadoop.mapreduce.Job: The url to track the job: http://localhost:8080/
# 2025-12-16 06:20:28,782 INFO  org.apache.hadoop.mapreduce.Job: Running job: job_local1082094662_0002
# 2025-12-16 06:20:28,788 INFO  org.apache.hadoop.mapred.LocalJobRunner: Starting task: attempt_local1082094662_0002_m_000000_0
# 2025-12-16 06:20:28,790 INFO  org.apache.hadoop.mapred.LocalJobRunner: Waiting for map tasks
# 2025-12-16 06:20:28,791 INFO  org.apache.hadoop.mapreduce.lib.output.PathOutputCommitterFactory: No output committer factory defined, defaulting to FileOutputCommitterFactory
# 2025-12-16 06:20:28,791 INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-12-16 06:20:28,791 INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-12-16 06:20:28,791 INFO  org.apache.hadoop.mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2025-12-16 06:20:28,795 INFO  org.apache.hadoop.mapred.MapTask: Processing split: file:/content/grep-temp-1938089632/part-r-00000:0+183
# 2025-12-16 06:20:28,827 INFO  org.apache.hadoop.mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2025-12-16 06:20:28,828 INFO  org.apache.hadoop.mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2025-12-16 06:20:28,828 INFO  org.apache.hadoop.mapred.MapTask: soft limit at 83886080
# 2025-12-16 06:20:28,829 INFO  org.apache.hadoop.mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2025-12-16 06:20:28,829 INFO  org.apache.hadoop.mapred.MapTask: kvstart = 26214396; length = 6553600
# 2025-12-16 06:20:28,831 INFO  org.apache.hadoop.mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2025-12-16 06:20:28,847 INFO  org.apache.hadoop.mapred.LocalJobRunner:
# 2025-12-16 06:20:28,849 INFO  org.apache.hadoop.mapred.MapTask: Starting flush of map output
# 2025-12-16 06:20:28,849 INFO  org.apache.hadoop.mapred.MapTask: Spilling map output
# 2025-12-16 06:20:28,849 INFO  org.apache.hadoop.mapred.MapTask: bufstart = 0; bufend = 65; bufvoid = 104857600
# 2025-12-16 06:20:28,849 INFO  org.apache.hadoop.mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214384(104857536); length = 13/6553600
# 2025-12-16 06:20:28,853 INFO  org.apache.hadoop.mapred.MapTask: Finished spill 0
# 2025-12-16 06:20:28,860 INFO  org.apache.hadoop.mapred.Task: Task:attempt_local1082094662_0002_m_000000_0 is done. And is in the process of committing
# 2025-12-16 06:20:28,865 INFO  org.apache.hadoop.mapred.LocalJobRunner: map
# 2025-12-16 06:20:28,865 INFO  org.apache.hadoop.mapred.Task: Task 'attempt_local1082094662_0002_m_000000_0' done.
# 2025-12-16 06:20:28,866 INFO  org.apache.hadoop.mapred.Task: Final Counters for attempt_local1082094662_0002_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=563444
# 		FILE: Number of bytes written=1840136
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=4
# 		Map output records=4
# 		Map output bytes=65
# 		Map output materialized bytes=79
# 		Input split bytes=112
# 		Combine input records=0
# 		Spilled Records=4
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=283115520
# 	File Input Format Counters
# 		Bytes Read=195
# 2025-12-16 06:20:28,867 INFO  org.apache.hadoop.mapred.LocalJobRunner: Finishing task: attempt_local1082094662_0002_m_000000_0
# 2025-12-16 06:20:28,867 INFO  org.apache.hadoop.mapred.LocalJobRunner: map task executor complete.
# 2025-12-16 06:20:28,870 INFO  org.apache.hadoop.mapred.LocalJobRunner: Waiting for reduce tasks
# 2025-12-16 06:20:28,870 INFO  org.apache.hadoop.mapred.LocalJobRunner: Starting task: attempt_local1082094662_0002_r_000000_0
# 2025-12-16 06:20:28,873 INFO  org.apache.hadoop.mapreduce.lib.output.PathOutputCommitterFactory: No output committer factory defined, defaulting to FileOutputCommitterFactory
# 2025-12-16 06:20:28,873 INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-12-16 06:20:28,873 INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-12-16 06:20:28,874 INFO  org.apache.hadoop.mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2025-12-16 06:20:28,874 INFO  org.apache.hadoop.mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@3011a4db
# 2025-12-16 06:20:28,874 WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2025-12-16 06:20:28,876 INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl: MergerManager: memoryLimit=2381106432, maxSingleShuffleLimit=595276608, mergeThreshold=1571530368, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2025-12-16 06:20:28,878 INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher: attempt_local1082094662_0002_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2025-12-16 06:20:28,882 INFO  org.apache.hadoop.mapreduce.task.reduce.LocalFetcher: localfetcher#2 about to shuffle output of map attempt_local1082094662_0002_m_000000_0 decomp: 75 len: 79 to MEMORY
# 2025-12-16 06:20:28,885 INFO  org.apache.hadoop.mapreduce.task.reduce.InMemoryMapOutput: Read 75 bytes from map-output for attempt_local1082094662_0002_m_000000_0
# 2025-12-16 06:20:28,887 INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 75, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->75
# 2025-12-16 06:20:28,888 INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2025-12-16 06:20:28,889 INFO  org.apache.hadoop.mapred.LocalJobRunner: 1 / 1 copied.
# 2025-12-16 06:20:28,889 INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2025-12-16 06:20:28,892 INFO  org.apache.hadoop.mapred.Merger: Merging 1 sorted segments
# 2025-12-16 06:20:28,892 INFO  org.apache.hadoop.mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 65 bytes
# 2025-12-16 06:20:28,898 INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl: Merged 1 segments, 75 bytes to disk to satisfy reduce memory limit
# 2025-12-16 06:20:28,899 INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl: Merging 1 files, 79 bytes from disk
# 2025-12-16 06:20:28,900 INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2025-12-16 06:20:28,900 INFO  org.apache.hadoop.mapred.Merger: Merging 1 sorted segments
# 2025-12-16 06:20:28,901 INFO  org.apache.hadoop.mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 65 bytes
# 2025-12-16 06:20:28,903 INFO  org.apache.hadoop.mapred.LocalJobRunner: 1 / 1 copied.
# 2025-12-16 06:20:28,914 INFO  org.apache.hadoop.mapred.Task: Task:attempt_local1082094662_0002_r_000000_0 is done. And is in the process of committing
# 2025-12-16 06:20:28,918 INFO  org.apache.hadoop.mapred.LocalJobRunner: 1 / 1 copied.
# 2025-12-16 06:20:28,918 INFO  org.apache.hadoop.mapred.Task: Task attempt_local1082094662_0002_r_000000_0 is allowed to commit now
# 2025-12-16 06:20:28,923 INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter: Saved output of task 'attempt_local1082094662_0002_r_000000_0' to file:/lineoutput
# 2025-12-16 06:20:28,926 INFO  org.apache.hadoop.mapred.LocalJobRunner: reduce > reduce
# 2025-12-16 06:20:28,926 INFO  org.apache.hadoop.mapred.Task: Task 'attempt_local1082094662_0002_r_000000_0' done.
# 2025-12-16 06:20:28,927 INFO  org.apache.hadoop.mapred.Task: Final Counters for attempt_local1082094662_0002_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=563634
# 		FILE: Number of bytes written=1840268
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=2
# 		Reduce shuffle bytes=79
# 		Reduce input records=4
# 		Reduce output records=4
# 		Spilled Records=4
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=283115520
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=53
# 2025-12-16 06:20:28,927 INFO  org.apache.hadoop.mapred.LocalJobRunner: Finishing task: attempt_local1082094662_0002_r_000000_0
# 2025-12-16 06:20:28,927 INFO  org.apache.hadoop.mapred.LocalJobRunner: reduce task executor complete.
# 2025-12-16 06:20:29,782 INFO  org.apache.hadoop.mapreduce.Job: Job job_local1082094662_0002 running in uber mode : false
# 2025-12-16 06:20:29,783 INFO  org.apache.hadoop.mapreduce.Job:  map 100% reduce 100%
# 2025-12-16 06:20:29,784 INFO  org.apache.hadoop.mapreduce.Job: Job job_local1082094662_0002 completed successfully
# 2025-12-16 06:20:29,787 INFO  org.apache.hadoop.mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=1127078
# 		FILE: Number of bytes written=3680404
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=4
# 		Map output records=4
# 		Map output bytes=65
# 		Map output materialized bytes=79
# 		Input split bytes=112
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=2
# 		Reduce shuffle bytes=79
# 		Reduce input records=4
# 		Reduce output records=4
# 		Spilled Records=8
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=566231040
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=195
# 	File Output Format Counters
# 		Bytes Written=53

# %%
#View Output
# %%bash
export JAVA_HOME=/usr/lib/jvm/java-17-openjdk-amd64
export HADOOP_HOME=/content/hadoop
export PATH=$PATH:$JAVA_HOME/bin:$HADOOP_HOME/bin:$HADOOP_HOME/sbin

hdfs dfs -cat /lineoutput/part-r-00000
# Out:
# 3
# 1	hello
# 1	hadoop mapreduce
# 1	big data
